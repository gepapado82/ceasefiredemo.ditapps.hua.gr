# %%
import numpy as np
from PIL import Image
import cv2
from matplotlib import pyplot as plt

# %%
hi_image = np.asarray(Image.open('hi.png')).astype(np.uint16)
# hi_image = cv2.imread('hi.png')
# hi_image = Image.fromarray(hi_image, 'RGB')
plt.imshow(hi_image, cmap="gray")
